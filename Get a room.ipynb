# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv('C://Users/Admin/Downloads/47417050-0-dataset/dataset/train.csv')

# %%
train_data.head()
# Out:
#   Property_ID Property_Type  Property_Area  Number_of_Windows  \
# 0      0x21e3     Apartment            106                NaN
# 1      0x68d4     Apartment            733                2.0
# 2      0x7d81     Apartment            737                4.0
# 3      0x7a57     Apartment            900                3.0
# 4      0x9409      Bungalow           2238               14.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1   Semi_Furnished                     0.0           No
# 1                2      Unfurnished                     1.0           No
# 2                2  Fully Furnished                     0.0           No
# 3                2      Unfurnished                     2.0          Yes
# 4                6  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   5.89  Slightly below average
# ...

# %%
train_data.head(20)
# Out:
#    Property_ID       Property_Type  Property_Area  Number_of_Windows  \
# 0       0x21e3           Apartment            106                NaN
# 1       0x68d4           Apartment            733                2.0
# 2       0x7d81           Apartment            737                4.0
# 3       0x7a57           Apartment            900                3.0
# 4       0x9409            Bungalow           2238               14.0
# 5       0xbe4e  Single-family home           1185                3.0
# 6        0xe2a  Single-family home           1779                3.0
# 7       0x2ea5              Duplex           1281                5.0
# 8       0x7a83           Apartment            268                1.0
# 9       0xb0fb           Apartment            159                2.0
# 10      0xaf2f           Apartment            521                1.0
# 11      0x6ffb            Bungalow           2164               13.0
# 12      0x6aca  Single-family home           1620                3.0
# ...

# %% [markdown]
# y_train = train_data.iloc[:, -1]

# %%
y_train = train_data.iloc[:,-1]

# %%
y_train
# Out:
# 0        71.98
# 1        71.20
# 2        71.39
# 3        31.46
# 4        93.70
# 5        82.94
# 6        74.88
# 7        28.54
# 8        88.11
# 9        80.65
# 10       73.51
# 11       87.91
# 12       76.86
# 13       71.31
# 14       72.35
# 15       79.82
# 16       72.19
# 17       83.68
# 18       77.28
# 19       73.46
# 20       89.95
# 21       84.58
# 22       81.38
# 23       85.51
# 24       75.63
# 25       64.38
# 26       29.97
# 27       78.07
# 28       80.07
# 29       22.32
#          ...
# 39469    86.53
# 39470    73.14
# 39471    74.28
# 39472    75.17
# 39473    79.71
# 39474    80.55
# 39475    75.40
# 39476    77.83
# 39477    40.83
# 39478    69.38
# 39479    72.91
# 39480    75.28
# 39481    27.82
# 39482    77.15
# 39483    76.06
# 39484    63.83
# 39485    77.70
# 39486    57.54
# 39487    79.02
# 39488    84.22
# 39489    84.77
# 39490    59.71
# 39491    86.55
# 39492    78.75
# 39493    73.61
# 39494    73.43
# 39495    79.91
# ...

# %%
y_train.isnull().any()
# Out:
# False

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
(y_train < 0).any()
# Out:
# False

# %%
X_train = train_data[['Property_Type', 'Property_Area', 'Number_of_Windows', 'Number_of_Doors', 'Furnishing', 'Frequency_of_Powercuts', 'Power_Backup', 'Water_Supply', 'Traffic_Density_Score', 'Crime_Rate', 'Dust_and_Noise', 'Air_Quality_Index', 'Neighborhood_Review']]

# %%
X_train.head()
# Out:
#   Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0     Apartment            106                NaN                1
# 1     Apartment            733                2.0                2
# 2     Apartment            737                4.0                2
# 3     Apartment            900                3.0                2
# 4      Bungalow           2238               14.0                6
#
#         Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0   Semi_Furnished                     0.0           No
# 1      Unfurnished                     1.0           No
# 2  Fully Furnished                     0.0           No
# 3      Unfurnished                     2.0          Yes
# 4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   5.89  Slightly below average
# ...

# %%
X_train.keys()
# Out:
# Index(['Property_Type', 'Property_Area', 'Number_of_Windows',
#        'Number_of_Doors', 'Furnishing', 'Frequency_of_Powercuts',
#        'Power_Backup', 'Water_Supply', 'Traffic_Density_Score', 'Crime_Rate',
#        'Dust_and_Noise', 'Air_Quality_Index', 'Neighborhood_Review'],
#       dtype='object')

# %%
X_train.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows          True
# Number_of_Doors           False
# Furnishing                 True
# Frequency_of_Powercuts     True
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                 True
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %% [raw]
# from sklearn.preprocessing import imputer

# %%
from sklearn.preprocessing import Imputer

# %%
imputer_windows = Imputer(missing_values = 'NaN', strategy='most_frequent')
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
X_train['Number_of_Windows'] = imputer_windows.fit_transform(X_train[['Number_of_Windows']])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train.head()
# Out:
#   Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0     Apartment            106                4.0                1
# 1     Apartment            733                2.0                2
# 2     Apartment            737                4.0                2
# 3     Apartment            900                3.0                2
# 4      Bungalow           2238               14.0                6
#
#         Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0   Semi_Furnished                     0.0           No
# 1      Unfurnished                     1.0           No
# 2  Fully Furnished                     0.0           No
# 3      Unfurnished                     2.0          Yes
# 4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   5.89  Slightly below average
# ...

# %%
X_train.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                 True
# Frequency_of_Powercuts     True
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                 True
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_train['Furnishing'].value_counts()
# Out:
# Semi_Furnished     20357
# Unfurnished        10344
# Fully Furnished     7756
# Name: Furnishing, dtype: int64

# %%
from sklearn_pandas import CategoricalImputer

# %%
cimputer_furnishing = CategoricalImputer()

# %%
X_train['Furnishing'] = cimputer_furnishing.fit_transform(X_train['Furnishing'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train['Furnishing'].value_counts()
# Out:
# Semi_Furnished     21399
# Unfurnished        10344
# Fully Furnished     7756
# Name: Furnishing, dtype: int64

# %%
X_train.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts     True
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                 True
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_train['Frequency_of_Powercuts'].value_counts()
# Out:
# 0.0    24471
# 1.0    10010
# 2.0     2441
# 3.0     1194
# Name: Frequency_of_Powercuts, dtype: int64

# %%
cimputer_frequency = CategoricalImputer()

# %%
X_train['Frequency_of_Powercuts'] = cimputer_frequency.fit_transform(X_train['Frequency_of_Powercuts'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train['Frequency_of_Powercuts'].value_counts()
# Out:
# 0.0    25854
# 1.0    10010
# 2.0     2441
# 3.0     1194
# Name: Frequency_of_Powercuts, dtype: int64

# %%
X_train.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts    False
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                 True
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_train['Crime_Rate'].value_counts()
# Out:
# Well below average        19472
# Slightly below average    11580
# Slightly above average     5303
# Well above average         2357
# Name: Crime_Rate, dtype: int64

# %%
cimputer_crime = CategoricalImputer()

# %%
X_train['Crime_Rate'] = cimputer_crime.fit_transform(X_train['Crime_Rate'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train['Crime_Rate'].value_counts()
# Out:
# Well below average        20259
# Slightly below average    11580
# Slightly above average     5303
# Well above average         2357
# Name: Crime_Rate, dtype: int64

# %%
X_train.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts    False
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                False
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_train['Dust_and_Noise'].value_counts()
# Out:
# Medium    32996
# High       3212
# Low        2072
# Name: Dust_and_Noise, dtype: int64

# %%
cimputer_dust = CategoricalImputer()

# %%
X_train['Dust_and_Noise'] = cimputer_dust.fit_transform(X_train['Dust_and_Noise'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train['Dust_and_Noise'].value_counts()
# Out:
# Medium    34215
# High       3212
# Low        2072
# Name: Dust_and_Noise, dtype: int64

# %%
X_train.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts    False
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                False
# Dust_and_Noise            False
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_train.head()
# Out:
#   Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0     Apartment            106                4.0                1
# 1     Apartment            733                2.0                2
# 2     Apartment            737                4.0                2
# 3     Apartment            900                3.0                2
# 4      Bungalow           2238               14.0                6
#
#         Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0   Semi_Furnished                     0.0           No
# 1      Unfurnished                     1.0           No
# 2  Fully Furnished                     0.0           No
# 3      Unfurnished                     2.0          Yes
# 4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   5.89  Slightly below average
# ...

# %%
y_train.isnull().any()
# Out:
# False

# %% [markdown]
# Done with the removing/filtering missing values

# %% [markdown]
# Label Encoder needs to be applied on
#
# 1) Property Type
# 2) Furnishing
# 3) Powerbackup
# 4) Water Supply
# 5) Crime Rate
# 6) Dust and Noise

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_property = LabelEncoder()

# %%
X_train['Property_Type'] = le_property.fit_transform(X_train['Property_Type'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            106                4.0                1
# 1              1            733                2.0                2
# 2              1            737                4.0                2
# 3              1            900                3.0                2
# 4              2           2238               14.0                6
#
#         Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0   Semi_Furnished                     0.0           No
# 1      Unfurnished                     1.0           No
# 2  Fully Furnished                     0.0           No
# 3      Unfurnished                     2.0          Yes
# 4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   5.89  Slightly below average
# ...

# %%
X_train['Property_Type'].value_counts()
# Out:
# 1    14596
# 5    11477
# 4     5806
# 2     4238
# 3     2872
# 0      510
# Name: Property_Type, dtype: int64

# %%
print("0: ",str(le_property.classes_[0]))
print("1: ",str(le_property.classes_[1]))
print("2: ",str(le_property.classes_[2]))
print("3: ",str(le_property.classes_[3]))
print("4: ",str(le_property.classes_[4]))
print("5: ",str(le_property.classes_[5]))
# Out:
# 0:  #R%$G&867
# 1:  Apartment
# 2:  Bungalow
# 3:  Container Home
# 4:  Duplex
# 5:  Single-family home

# %%
X_train['Furnishing'].value_counts()
# Out:
# Semi_Furnished     21399
# Unfurnished        10344
# Fully Furnished     7756
# Name: Furnishing, dtype: int64

# %%
le_furnish = LabelEncoder()

# %%
X_train['Furnishing'] = le_furnish.fit_transform(X_train['Furnishing'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print("0: ",str(le_furnish.classes_[0]))
print("1: ",str(le_furnish.classes_[1]))
print("2: ",str(le_furnish.classes_[2]))
# Out:
# 0:  Fully Furnished
# 1:  Semi_Furnished
# 2:  Unfurnished

# %%
X_train['Power_Backup'].value_counts()
# Out:
# No               29714
# Yes               8957
# NOT MENTIONED      828
# Name: Power_Backup, dtype: int64

# %%
le_power = LabelEncoder()

# %%
X_train['Power_Backup'] = le_power.fit_transform(X_train['Power_Backup'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print("0: ",str(le_power.classes_[0]))
print("1: ",str(le_power.classes_[1]))
print("2: ",str(le_power.classes_[2]))
# Out:
# 0:  NOT MENTIONED
# 1:  No
# 2:  Yes

# %%
X_train['Water_Supply'].value_counts()
# Out:
# All time                   19511
# Once in a day - Morning     9897
# Once in a day - Evening     7815
# Once in two days            1931
# NOT MENTIONED                345
# Name: Water_Supply, dtype: int64

# %%
le_water = LabelEncoder()

# %%
X_train['Water_Supply'] = le_water.fit_transform(X_train['Water_Supply'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print("0: ",str(le_water.classes_[0]))
print("1: ",str(le_water.classes_[1]))
print("2: ",str(le_water.classes_[2]))
print("3: ",str(le_water.classes_[3]))
print("4: ",str(le_water.classes_[4]))
# Out:
# 0:  All time
# 1:  NOT MENTIONED
# 2:  Once in a day - Evening
# 3:  Once in a day - Morning
# 4:  Once in two days

# %%
X_train['Crime_Rate'].value_counts()
# Out:
# Well below average        20259
# Slightly below average    11580
# Slightly above average     5303
# Well above average         2357
# Name: Crime_Rate, dtype: int64

# %%
le_crime = LabelEncoder()

# %%
X_train['Crime_Rate'] = le_crime.fit_transform(X_train['Crime_Rate'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print("0: ",str(le_crime.classes_[0]))
print("1: ",str(le_crime.classes_[1]))
print("2: ",str(le_crime.classes_[2]))
print("3: ",str(le_crime.classes_[3]))
# Out:
# 0:  Slightly above average
# 1:  Slightly below average
# 2:  Well above average
# 3:  Well below average

# %%
X_train['Dust_and_Noise'].value_counts()
# Out:
# Medium    34215
# High       3212
# Low        2072
# Name: Dust_and_Noise, dtype: int64

# %%
le_dust = LabelEncoder()

# %%
X_train['Dust_and_Noise'] = le_dust.fit_transform(X_train['Dust_and_Noise'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print("0: ",str(le_dust.classes_[0]))
print("1: ",str(le_dust.classes_[1]))
print("2: ",str(le_dust.classes_[2]))
# Out:
# 0:  High
# 1:  Low
# 2:  Medium

# %%
X_train.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            106                4.0                1
# 1              1            733                2.0                2
# 2              1            737                4.0                2
# 3              1            900                3.0                2
# 4              2           2238               14.0                6
#
#    Furnishing  Frequency_of_Powercuts  Power_Backup  Water_Supply  \
# 0           1                     0.0             1             3
# 1           2                     1.0             1             2
# 2           0                     0.0             1             3
# 3           2                     2.0             2             3
# 4           0                     0.0             1             0
#
#    Traffic_Density_Score  Crime_Rate  Dust_and_Noise  Air_Quality_Index  \
# 0                   5.89           1               2               90.0
# ...

# %%
X_train.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts    False
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                False
# Dust_and_Noise            False
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_train.isnull().sum()
# Out:
# Property_Type             0
# Property_Area             0
# Number_of_Windows         0
# Number_of_Doors           0
# Furnishing                0
# Frequency_of_Powercuts    0
# Power_Backup              0
# Water_Supply              0
# Traffic_Density_Score     0
# Crime_Rate                0
# Dust_and_Noise            0
# Air_Quality_Index         0
# Neighborhood_Review       0
# dtype: int64

# %%
X_train
# Out:
#        Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0                  1            106                4.0                1
# 1                  1            733                2.0                2
# 2                  1            737                4.0                2
# 3                  1            900                3.0                2
# 4                  2           2238               14.0                6
# 5                  5           1185                3.0                3
# 6                  5           1779                3.0                3
# 7                  4           1281                5.0                2
# 8                  1            268                1.0                3
# 9                  1            159                2.0                2
# 10                 1            521                1.0                2
# 11                 2           2164               13.0                4
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model_linear = LinearRegression()

# %%
model_linear.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model_linear.score(X_train, y_train) * 100
# Out:
# 56.5084280488225

# %% [markdown]
# Need to pre-process the testing dataset, predict the testing data

# %%
test_data = pd.read_csv('C://Users/Admin/Downloads/47417050-0-dataset/dataset/test.csv')

# %%
test_data.head()
# Out:
#   Property_ID   Property_Type  Property_Area  Number_of_Windows  \
# 0      0x6e93       Apartment            293                3.0
# 1      0x8787       Apartment            586                4.0
# 2      0x6c17  Container Home            305                1.0
# 3      0x9dbd       Apartment            258                2.0
# 4      0xbfde        Bungalow           3031               12.0
#
#    Number_of_Doors       Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0                1      Unfurnished                     0.0           No
# 1                1   Semi_Furnished                     0.0           No
# 2                2   Semi_Furnished                     1.0           No
# 3                1   Semi_Furnished                     1.0           No
# 4                4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# ...

# %%
X_test = test_data[['Property_Type', 'Property_Area', 'Number_of_Windows', 'Number_of_Doors', 'Furnishing', 'Frequency_of_Powercuts', 'Power_Backup', 'Water_Supply', 'Traffic_Density_Score', 'Crime_Rate', 'Dust_and_Noise', 'Air_Quality_Index', 'Neighborhood_Review']]

# %%
X_test.head()
# Out:
#     Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0       Apartment            293                3.0                1
# 1       Apartment            586                4.0                1
# 2  Container Home            305                1.0                2
# 3       Apartment            258                2.0                1
# 4        Bungalow           3031               12.0                4
#
#         Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0      Unfurnished                     0.0           No
# 1   Semi_Furnished                     0.0           No
# 2   Semi_Furnished                     1.0           No
# 3   Semi_Furnished                     1.0           No
# 4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   7.28      Well above average
# ...

# %%
X_test.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows          True
# Number_of_Doors           False
# Furnishing                 True
# Frequency_of_Powercuts     True
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                 True
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
test_imputer_windows = Imputer(missing_values='NaN', strategy='most_frequent')
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
X_test['Number_of_Windows'] = test_imputer_windows.fit_transform(X_test[['Number_of_Windows']])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                 True
# Frequency_of_Powercuts     True
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                 True
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
test_cimputer_furnish = CategoricalImputer()

# %%
X_test['Furnishing'].value_counts()
# Out:
# Semi_Furnished     5675
# Unfurnished        2659
# Fully Furnished    2166
# Name: Furnishing, dtype: int64

# %%
X_test['Furnishing'] = test_cimputer_furnish.fit_transform(X_test['Furnishing'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts     True
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                 True
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_test['Frequency_of_Powercuts'].value_counts()
# Out:
# 0.0    6861
# 1.0    2681
# 2.0     646
# 3.0     312
# Name: Frequency_of_Powercuts, dtype: int64

# %%
test_cimputer_powercut = CategoricalImputer()

# %%
X_test['Frequency_of_Powercuts'] = test_cimputer_powercut.fit_transform(X_test['Frequency_of_Powercuts'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts    False
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                False
# Dust_and_Noise             True
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_test['Crime_Rate'].value_counts()
# Out:
# Well below average        5401
# Slightly below average    3032
# Slightly above average    1421
# Well above average         646
# Name: Crime_Rate, dtype: int64

# %%
test_cimputer_crime = CategoricalImputer()

# %%
X_test['Crime_Rate'] = test_cimputer_crime.fit_transform(X_test['Crime_Rate'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test['Dust_and_Noise'].value_counts()
# Out:
# Medium    8826
# High       802
# Low        542
# Name: Dust_and_Noise, dtype: int64

# %%
test_cimputer_dust = CategoricalImputer()

# %%
X_test['Dust_and_Noise'] = test_cimputer_dust.fit_transform(X_test['Dust_and_Noise'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts    False
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                False
# Dust_and_Noise            False
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_test.head()
# Out:
#     Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0       Apartment            293                3.0                1
# 1       Apartment            586                4.0                1
# 2  Container Home            305                1.0                2
# 3       Apartment            258                2.0                1
# 4        Bungalow           3031               12.0                4
#
#         Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0      Unfurnished                     0.0           No
# 1   Semi_Furnished                     0.0           No
# 2   Semi_Furnished                     1.0           No
# 3   Semi_Furnished                     1.0           No
# 4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   7.28      Well above average
# ...

# %%
test_le_property_type = LabelEncoder()

# %%
X_test['Property_Type'] = test_le_property_type.fit_transform(X_test['Property_Type'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            293                3.0                1
# 1              1            586                4.0                1
# 2              3            305                1.0                2
# 3              1            258                2.0                1
# 4              2           3031               12.0                4
#
#         Furnishing  Frequency_of_Powercuts Power_Backup  \
# 0      Unfurnished                     0.0           No
# 1   Semi_Furnished                     0.0           No
# 2   Semi_Furnished                     1.0           No
# 3   Semi_Furnished                     1.0           No
# 4  Fully Furnished                     0.0           No
#
#               Water_Supply  Traffic_Density_Score              Crime_Rate  \
# 0  Once in a day - Morning                   7.28      Well above average
# ...

# %%
test_le_furnish = LabelEncoder()

# %%
X_test['Furnishing'] = test_le_furnish.fit_transform(X_test['Furnishing'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            293                3.0                1
# 1              1            586                4.0                1
# 2              3            305                1.0                2
# 3              1            258                2.0                1
# 4              2           3031               12.0                4
#
#    Furnishing  Frequency_of_Powercuts Power_Backup             Water_Supply  \
# 0           2                     0.0           No  Once in a day - Morning
# 1           1                     0.0           No  Once in a day - Evening
# 2           1                     1.0           No                 All time
# 3           1                     1.0           No                 All time
# 4           0                     0.0           No                 All time
#
#    Traffic_Density_Score              Crime_Rate Dust_and_Noise  \
# ...

# %%
test_le_power = LabelEncoder()

# %%
X_test['Power_Backup'] = test_le_power.fit_transform(X_test['Power_Backup'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            293                3.0                1
# 1              1            586                4.0                1
# 2              3            305                1.0                2
# 3              1            258                2.0                1
# 4              2           3031               12.0                4
#
#    Furnishing  Frequency_of_Powercuts  Power_Backup             Water_Supply  \
# 0           2                     0.0             1  Once in a day - Morning
# 1           1                     0.0             1  Once in a day - Evening
# 2           1                     1.0             1                 All time
# 3           1                     1.0             1                 All time
# 4           0                     0.0             1                 All time
#
#    Traffic_Density_Score              Crime_Rate Dust_and_Noise  \
# ...

# %%
test_le_water = LabelEncoder()

# %%
X_test['Water_Supply'] = test_le_water.fit_transform(X_test['Water_Supply'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            293                3.0                1
# 1              1            586                4.0                1
# 2              3            305                1.0                2
# 3              1            258                2.0                1
# 4              2           3031               12.0                4
#
#    Furnishing  Frequency_of_Powercuts  Power_Backup  Water_Supply  \
# 0           2                     0.0             1             3
# 1           1                     0.0             1             2
# 2           1                     1.0             1             0
# 3           1                     1.0             1             0
# 4           0                     0.0             1             0
#
#    Traffic_Density_Score              Crime_Rate Dust_and_Noise  \
# 0                   7.28      Well above average         Medium
# ...

# %%
test_le_crime = LabelEncoder()

# %%
X_test['Crime_Rate'] = test_le_crime.fit_transform(X_test['Crime_Rate'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            293                3.0                1
# 1              1            586                4.0                1
# 2              3            305                1.0                2
# 3              1            258                2.0                1
# 4              2           3031               12.0                4
#
#    Furnishing  Frequency_of_Powercuts  Power_Backup  Water_Supply  \
# 0           2                     0.0             1             3
# 1           1                     0.0             1             2
# 2           1                     1.0             1             0
# 3           1                     1.0             1             0
# 4           0                     0.0             1             0
#
#    Traffic_Density_Score  Crime_Rate Dust_and_Noise  Air_Quality_Index  \
# 0                   7.28           2         Medium              152.0
# ...

# %%
test_le_dust = LabelEncoder()

# %%
X_test['Dust_and_Noise'] = test_le_dust.fit_transform(X_test['Dust_and_Noise'])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            293                3.0                1
# 1              1            586                4.0                1
# 2              3            305                1.0                2
# 3              1            258                2.0                1
# 4              2           3031               12.0                4
#
#    Furnishing  Frequency_of_Powercuts  Power_Backup  Water_Supply  \
# 0           2                     0.0             1             3
# 1           1                     0.0             1             2
# 2           1                     1.0             1             0
# 3           1                     1.0             1             0
# 4           0                     0.0             1             0
#
#    Traffic_Density_Score  Crime_Rate  Dust_and_Noise  Air_Quality_Index  \
# 0                   7.28           2               2              152.0
# ...

# %%
X_test.head()
# Out:
#    Property_Type  Property_Area  Number_of_Windows  Number_of_Doors  \
# 0              1            293                3.0                1
# 1              1            586                4.0                1
# 2              3            305                1.0                2
# 3              1            258                2.0                1
# 4              2           3031               12.0                4
#
#    Furnishing  Frequency_of_Powercuts  Power_Backup  Water_Supply  \
# 0           2                     0.0             1             3
# 1           1                     0.0             1             2
# 2           1                     1.0             1             0
# 3           1                     1.0             1             0
# 4           0                     0.0             1             0
#
#    Traffic_Density_Score  Crime_Rate  Dust_and_Noise  Air_Quality_Index  \
# 0                   7.28           2               2              152.0
# ...

# %%
X_test.isnull().any()
# Out:
# Property_Type             False
# Property_Area             False
# Number_of_Windows         False
# Number_of_Doors           False
# Furnishing                False
# Frequency_of_Powercuts    False
# Power_Backup              False
# Water_Supply              False
# Traffic_Density_Score     False
# Crime_Rate                False
# Dust_and_Noise            False
# Air_Quality_Index         False
# Neighborhood_Review       False
# dtype: bool

# %%
X_test.isnull().sum()
# Out:
# Property_Type             0
# Property_Area             0
# Number_of_Windows         0
# Number_of_Doors           0
# Furnishing                0
# Frequency_of_Powercuts    0
# Power_Backup              0
# Water_Supply              0
# Traffic_Density_Score     0
# Crime_Rate                0
# Dust_and_Noise            0
# Air_Quality_Index         0
# Neighborhood_Review       0
# dtype: int64

# %%
prediction = model_linear.predict(X_test)

# %%
prediction
# Out:
# array([45.74828211, 73.56606519, 64.85663085, ..., 84.38989699,
#        70.1186637 , 75.2041105 ])

# %%
result = pd.DataFrame([test_data['Property_ID'], prediction], index=['Property_ID', 'Habitability_score']).T
result.to_csv('C://Users/Admin/Documents/get_a_room_linear_model.csv', index=False)
result.head()
# Out:
#   Property_ID Habitability_score
# 0      0x6e93            45.7483
# 1      0x8787            73.5661
# 2      0x6c17            64.8566
# 3      0x9dbd            68.3682
# 4      0xbfde            67.4941

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators=250)

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=250, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
prediction_rfr = rfr.predict(X_test)

# %%
rfr.score(X_train, y_train) * 100
# Out:
# 97.59642388556536

# %%
result_rfr = pd.DataFrame([test_data['Property_ID'], prediction_rfr], index=['Property_ID', 'Habitability_score']).T
result_rfr.to_csv('C://Users/Admin/Documents/get_a_room_rfr_250.csv', index=False)
result_rfr.head()
# Out:
#   Property_ID Habitability_score
# 0      0x6e93            30.6416
# 1      0x8787             80.717
# 2      0x6c17            67.0012
# 3      0x9dbd            74.2162
# 4      0xbfde            75.4324
